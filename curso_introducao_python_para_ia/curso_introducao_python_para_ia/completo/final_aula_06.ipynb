# %%
# !pip install langchain==0.3.0
# !pip install langchain-groq==0.2.0
# Out:
# Requirement already satisfied: langchain==0.3.0 in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.3.0) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.3.0) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.3.0) (3.10.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.3.0) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.3.0) (0.3.1)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.3.0) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain==0.3.0) (0.1.121)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.3.0) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.3.0) (2.9.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain==0.3.0) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.3.0) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.3.0) (1.11.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.0->langchain==0.3.0) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.0->langchain==0.3.0) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.0->langchain==0.3.0) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (3.10.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.0) (2.23.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.3.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.3.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.3.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.3.0) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.0) (3.1.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (1.0.5)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.0->langchain==0.3.0) (3.0.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.3.0) (1.2.2)
# Requirement already satisfied: langchain-groq==0.2.0 in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: groq<1,>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from langchain-groq==0.2.0) (0.11.0)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in /usr/local/lib/python3.10/dist-packages (from langchain-groq==0.2.0) (0.3.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (0.27.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (2.9.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from groq<1,>=0.4.1->langchain-groq==0.2.0) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.117 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (0.1.121)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (24.1)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (8.5.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (3.8)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.117->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (3.10.7)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.117->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (2.32.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.4.1->langchain-groq==0.2.0) (2.23.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.117->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.117->langchain-core<0.4,>=0.3->langchain-groq==0.2.0) (2.0.7)

# %% [markdown]
# # Aula 6: Criando nosso primeiro ChatBot

# %%
import os
from langchain_groq import ChatGroq
from langchain.prompts import ChatPromptTemplate

api_key = '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'

os.environ['GROQ_API_KEY'] = api_key

chat = ChatGroq(model='llama-3.1-70b-versatile')


def resposta_do_bot(lista_mensagens):
  template = ChatPromptTemplate.from_messages(
      [('system', 'Você é um assistente amigável chamado Asimo')] +
      lista_mensagens
  )
  chain = template | chat
  return chain.invoke({}).content

print('Bem-vindo ao ChatBot da Asimo! (Digite x se você quiser sair!)\n')
mensagens = []
while True:
  pergunta = input('Usuário: ')
  if pergunta.lower() == 'x':
    break
  mensagens.append(('user', pergunta))
  resposta = resposta_do_bot(mensagens)
  mensagens.append(('assistant', resposta))
  print(f'Bot: {resposta}')

print('\nMuito obrigado por utilizar o AsimoBot!')
# Out:
# Bem-vindo ao ChatBot da Asimo! (Digite x se você quiser sair!)
#
# Usuário: Olá
# Bot: Olá! Sou o Asimo, seu assistente amigável. Estou aqui para ajudar com qualquer coisa que você precise. Como posso ser útil hoje?
# Usuário: Quem sou eu?
# Bot: Você é a pessoa que está conversando comigo agora! Infelizmente, não tenho informações adicionais sobre sua identidade pessoal, pois nossa conversa acabou de começar. Mas posso dizer que você é alguém que está procurando conversar comigo, o Asimo! Quer me contar um pouco sobre si mesmo?
# Usuário: Meu nome é Adriano
# Bot: Prazer em conhecer você, Adriano! É um prazer conversar com você. Como posso ser útil hoje? Você tem alguma pergunta, precisa de ajuda com algo ou simplesmente quer conversar? Estou aqui para ouvir!
# Usuário: x
#
# Muito obrigado por utilizar o AsimoBot!

# %% [markdown]
# ## Trabalhando com templates de Prompts

# %% [markdown]
# ### O que é um prompt?

# %% [markdown]
# Um prompt é uma instrução ou uma solicitação que você fornece a um modelo de linguagem para gerar uma resposta ou um texto. Ele serve como um ponto de partida para a interação, orientando o modelo sobre o que você deseja que ele produza. Resumindo, o prompt é a entrada na forma de texto que é processada pelo modelo para geração de uma resposta. Ele deve sempre ser claro e específico.
#
# Para entender melhor, imagine que você está conversando com um chef de cozinha. Se você disser "Faça algo gostoso", o chef pode interpretar isso de várias maneiras, resultando em pratos diferentes. No entanto, se você especificar "Prepare uma lasanha vegetariana", o chef terá uma direção clara e poderá criar exatamente o que você deseja. Da mesma forma, um prompt bem formulado fornece ao modelo de linguagem uma orientação precisa, permitindo que ele gere respostas mais relevantes e alinhadas com suas expectativas.

# %% [markdown]
# ### O que é um template de Prompt?

# %% [markdown]
# Um template de prompt (ou PromptTemplate) é uma estrutura pré-definida que permite criar prompts de forma mais organizada e reutilizável ao interagir com modelos de linguagem. Ele funciona como um molde que pode ser preenchido com variáveis ou informações específicas, facilitando a geração de prompts consistentes e adaptáveis para diferentes contextos ou tarefas. Ao utilizar um PromptTemplate, você pode economizar tempo e garantir que a formulação do prompt siga um padrão desejado, o que pode melhorar a qualidade das respostas geradas pelo modelo. Essa abordagem é especialmente útil em aplicações onde você precisa gerar múltiplos prompts semelhantes, como em chatbots como é o nosso caso.
#
# Vamos a exemplos...

# %%
from langchain.prompts import ChatPromptTemplate

template = ChatPromptTemplate.from_messages(
    [('user', 'Traduza {expressao} para a lingua {lingua}')]
)
print(template)
# Out:
# input_variables=['expressao', 'lingua'] input_types={} partial_variables={} messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['expressao', 'lingua'], input_types={}, partial_variables={}, template='Traduza {expressao} para a lingua {lingua}'), additional_kwargs={})]

# %%
template.invoke({'expressao': 'Beleza?', 'lingua': 'inglesa'})
# Out:
# ChatPromptValue(messages=[HumanMessage(content='Traduza Beleza? para a lingua inglesa', additional_kwargs={}, response_metadata={})])

# %% [markdown]
# ## Criando uma chain

# %% [markdown]
# Uma "chain" (ou cadeia) refere-se a uma sequência de operações ou etapas que são encadeadas para processar informações e gerar resultados de forma estruturada. Cada etapa na chain pode envolver diferentes componentes, como prompts, modelos de linguagem, ferramentas de processamento de dados ou chamadas a APIs, permitindo que construamos fluxos de trabalho complexos e personalizados.

# %%
import os
from langchain_groq import ChatGroq

api_key = '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'
os.environ['GROQ_API_KEY'] = api_key

chat = ChatGroq(model='llama-3.1-70b-versatile')

# %%
from langchain.prompts import ChatPromptTemplate

template = ChatPromptTemplate.from_messages(
    [('user', 'Traduza {expressao} para a lingua {lingua}')]
)

# %%
chain = template | chat

# %%
resposta = chain.invoke({'expressao': 'Beleza?', 'lingua': 'inglesa'})

# %%
print(resposta.content)
# Out:
# A tradução de "Beleza?" para a língua inglesa é "Beauty?"

# %%
from langchain.prompts import ChatPromptTemplate

template = ChatPromptTemplate.from_messages(
    [('system', 'Você é um assistente que sempre responde com piadas'),
     ('user', 'Traduza {expressao} para a lingua {lingua}')]
)
chain = template | chat
resposta = chain.invoke({'expressao': 'Beleza?', 'lingua': 'inglesa'})
print(resposta.content)
# Out:
# Beleza? É fácil, é só "Beauty"!
#
# Mas, brincando, a tradução correta seria "Beautiful", porque "beleza" é um adjetivo que descreve algo lindo.
#
# E você sabia que a beleza é subjetiva? É como o humor, cada um tem o seu!
#
# Por que a beleza foi ao médico? Porque estava se sentindo um pouco "desfigurada"!

# %% [markdown]
# ## Continuando o projeto lá da aula 3

# %%
def resposta_bot(mensagens):
  return 'Resposta do bot'

print('Bem-vindo ao AsimoBot')

mensagens = []
while True:
  pergunta = input('Usuario: ')
  if pergunta.lower() == 'x':
    break
  mensagens.append({'role': 'user', 'content': pergunta})
  resposta = resposta_bot(mensagens)
  mensagens.append({'role': 'assistant', 'content': resposta})
  print(f'Bot: {resposta}')

print('Muito obrigado por usar o AsimoBot')
print(mensagens)

# %%
import os
from langchain_groq import ChatGroq
from langchain.prompts import ChatPromptTemplate

api_key = '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'
os.environ['GROQ_API_KEY'] = api_key

chat = ChatGroq(model='llama-3.1-70b-versatile')

def resposta_bot(mensagens):
  mensagens_modelo = [('system', 'Você é um assistente amigável chamado Asimo')]
  mensagens_modelo += mensagens
  template = ChatPromptTemplate.from_messages(mensagens_modelo)
  chain = template | chat
  return chain.invoke({}).content

print('Bem-vindo ao AsimoBot')

mensagens = []
while True:
  pergunta = input('Usuario: ')
  if pergunta.lower() == 'x':
    break
  mensagens.append(('user', pergunta))
  resposta = resposta_bot(mensagens)
  mensagens.append(('assistant', resposta))
  print(f'Bot: {resposta}')

print('Muito obrigado por usar o AsimoBot')
print(mensagens)
# Out:
# Bem-vindo ao AsimoBot
# Usuario: Olá
# Bot: Olá! Estou aqui para ajudar. Meu nome é Asimo, prazer em conhecê-lo! Em que posso ajudá-lo hoje?
# Usuario: O que é langchain?
# Bot: Langchain é uma biblioteca de código aberto em Python que permite criar e gerenciar cadeias de linguagem (language chains) para tarefas de processamento de linguagem natural (NLP). Uma cadeia de linguagem é uma sequência de funções que processam e transformam texto de entrada em uma saída desejada.
#
# A Langchain foi projetada para simplificar o desenvolvimento de aplicativos de NLP, permitindo que os desenvolvedores criem modelos de linguagem mais complexos e personalizados. Ela fornece uma estrutura para combinar diferentes modelos de linguagem e algoritmos de NLP em uma única cadeia de processamento.
#
# Algumas das funcionalidades principais da Langchain incluem:
#
# * Suporte a modelos de linguagem de última geração, como LLMs (Large Language Models)
# * Capacidade de criar e gerenciar cadeias de linguagem personalizadas
# * Integração com bibliotecas de NLP populares, como Hugging Face Transformers e spaCy
#
# A Langchain é amplamente utilizada em aplicações de NLP, como:
#
# * Análise de sentimentos
# * Classificação de texto
# * Geração de texto
# * Tradução automática
#
# Você tem alguma experiência com NLP ou está interessado em aprender mais sobre a Langchain?
# Usuario: x
# Muito obrigado por usar o AsimoBot
# [('user', 'Olá'), ('assistant', 'Olá! Estou aqui para ajudar. Meu nome é Asimo, prazer em conhecê-lo! Em que posso ajudá-lo hoje?'), ('user', 'O que é langchain?'), ('assistant', 'Langchain é uma biblioteca de código aberto em Python que permite criar e gerenciar cadeias de linguagem (language chains) para tarefas de processamento de linguagem natural (NLP). Uma cadeia de linguagem é uma sequência de funções que processam e transformam texto de entrada em uma saída desejada.\n\nA Langchain foi projetada para simplificar o desenvolvimento de aplicativos de NLP, permitindo que os desenvolvedores criem modelos de linguagem mais complexos e personalizados. Ela fornece uma estrutura para combinar diferentes modelos de linguagem e algoritmos de NLP em uma única cadeia de processamento.\n\nAlgumas das funcionalidades principais da Langchain incluem:\n\n* Suporte a modelos de linguagem de última geração, como LLMs (Large Language Models)\n* Capacidade de criar e gerenciar cadeias de linguagem personalizadas\n* Integração com bibliotecas de NLP populares, como Hugging Face Transformers e spaCy\n\nA Langchain é amplamente utilizada em aplicações de NLP, como:\n\n* Análise de sentimentos\n* Classificação de texto\n* Geração de texto\n* Tradução automática\n\nVocê tem alguma experiência com NLP ou está interessado em aprender mais sobre a Langchain?')]
